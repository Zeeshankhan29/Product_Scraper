# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests

from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
search=input('Enter the input to search',)
No_of_pages=int(input('Enter the no of pages to extract the information'))

reviews=[]

for i in range(1,No_of_pages+1,1):
    url='https://www.flipkart.com/search?q='
    flipkart_page=requests.get(url+search+"&page"+str(i))
    flipkart_html=bs(flipkart_page.text,'html.parser')
    products=flipkart_html.findAll('div',{"class":"_4rR01T"})
    Product_description=flipkart_html.findAll('ul',{"class":"_1xgFaf"})
    Product_price=flipkart_html.findAll('div',{"class":"_30jeq3 _1_WHN1"})
    Ratings=flipkart_html.findAll('div',{"class":"_3LWZlK"})[0:25]
    image_url=flipkart_html.findAll('div',{"class":"_2QcLo-"})
  

    
    for i in range(1,24):
        try:
            product_name=products[i].text

        except:
            product_name='No name'
       
        try:
            product_description=Product_description[i].text
        except:
            product_description='No description'
        
        try:
            product_price=Product_price[i].text
        except:
            product_price='No price'
       
        try:
            product_ratings=Ratings[0:25][i].text
        except:
            product_ratings='No ratings'
        
        try:
            product_image=image_url[i].div.div.img['src']
        except:
            product_image='No image'
       
        mydict=({"Product_name": product_name, "Product_Description": product_description,
                     'Product_price': product_price, 'Product_ratings': product_ratings, "Image": product_image})
        reviews.append(mydict)
# Out:
# Enter the input to searchiphone13
# Enter the no of pages to extract the information3

# %%
reviews
# Out:
# [{'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Midnight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/f/c/g/iphone-13-mlpf3hn-a-apple-original-imag6vzzzfa5ndzm.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/y/n/y/apple-iphone-11-mhda3hn-a-original-imafwqepdb3fxtug.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/3/x/e/apple-iphone-11-mhdc3hn-a-original-imafwqepx5yxwctc.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 128 GB)',
#   'Product_Description': '128 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹35,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/d/d/s/apple-iphone-11-mhdj3hn-a-original-imafwqepmfedbhb2.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/x/g/b/apple-iphone-11-mhdm3hn-a-original-imafwqepgzwzwucu.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 64 GB)',
#   'Product_Description': '64 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹30,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 512 GB)',
#   'Product_Description': '512 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹1,04,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/l0igvww0/mobile/r/q/m/-original-imagca5ajerqpfjy.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Red, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/c/u/7/apple-iphone-11-mhdd3hn-a-original-imafwqephghanvyr.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/5/x/8/apple-iphone-11-mhdh3hn-a-original-imafwqepcdfxrmhn.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/g/k/e/apple-iphone-11-mhdf3hn-a-original-imafwqepygpnkgez.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/4/b/f/apple-iphone-11-mhdn3hn-a-original-imafwqeps9gkq9zd.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Red, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/5/9/g/apple-iphone-11-mhdk3hn-a-original-imafwqepg5dyc5dz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 12 Mini (Red, 64 GB)',
#   'Product_Description': '64 GB ROM13.72 cm (5.4 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA14 Bionic Chip with Next Generation Neural Engine ProcessorCeramic ShieldIndustry-leading IP68 Water ResistanceAll Screen OLED Display12MP TrueDepth Front Camera with Night Mode, 4K Dolby Vision HDR RecordingBrand Warranty for 1 Year',
#   'Product_price': '₹49,999',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kg8avm80/mobile/n/2/u/apple-iphone-12-mini-dummyapplefsn-original-imafwgbf4pvjhypq.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Midnight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/f/c/g/iphone-13-mlpf3hn-a-apple-original-imag6vzzzfa5ndzm.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/y/n/y/apple-iphone-11-mhda3hn-a-original-imafwqepdb3fxtug.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/3/x/e/apple-iphone-11-mhdc3hn-a-original-imafwqepx5yxwctc.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 128 GB)',
#   'Product_Description': '128 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹35,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/d/d/s/apple-iphone-11-mhdj3hn-a-original-imafwqepmfedbhb2.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/x/g/b/apple-iphone-11-mhdm3hn-a-original-imafwqepgzwzwucu.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 64 GB)',
#   'Product_Description': '64 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹30,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 512 GB)',
#   'Product_Description': '512 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹1,04,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/l0igvww0/mobile/r/q/m/-original-imagca5ajerqpfjy.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Red, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/c/u/7/apple-iphone-11-mhdd3hn-a-original-imafwqephghanvyr.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/5/x/8/apple-iphone-11-mhdh3hn-a-original-imafwqepcdfxrmhn.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/g/k/e/apple-iphone-11-mhdf3hn-a-original-imafwqepygpnkgez.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Red, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/5/9/g/apple-iphone-11-mhdk3hn-a-original-imafwqepg5dyc5dz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kgiaykw0/mobile/4/b/f/apple-iphone-11-mhdn3hn-a-original-imafwqeps9gkq9zd.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 12 Mini (Green, 64 GB)',
#   'Product_Description': '64 GB ROM13.72 cm (5.4 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA14 Bionic Chip with Next Generation Neural Engine ProcessorCeramic ShieldIndustry-leading IP68 Water ResistanceAll Screen OLED Display12MP TrueDepth Front Camera with Night Mode, 4K Dolby Vision HDR RecordingBrand Warranty for 1 Year',
#   'Product_price': '₹49,999',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim1.flixcart.com/image/312/312/kg8avm80/mobile/h/v/w/apple-iphone-12-mini-dummyapplefsn-original-imafwgb2zuc9gwgb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Midnight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/f/c/g/iphone-13-mlpf3hn-a-apple-original-imag6vzzzfa5ndzm.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Pink, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/z/r/x/iphone-13-mlph3hn-a-apple-original-imag6vzz4rt8t7gk.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/y/n/y/apple-iphone-11-mhda3hn-a-original-imafwqepdb3fxtug.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/3/x/e/apple-iphone-11-mhdc3hn-a-original-imafwqepx5yxwctc.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 128 GB)',
#   'Product_Description': '128 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹35,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (White, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/d/d/s/apple-iphone-11-mhdj3hn-a-original-imafwqepmfedbhb2.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/x/g/b/apple-iphone-11-mhdm3hn-a-original-imafwqepgzwzwucu.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone SE (Red, 64 GB)',
#   'Product_Description': '64 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty of 1 Year',
#   'Product_price': '₹30,499',
#   'Product_ratings': '4.5',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/k9loccw0/mobile/6/8/g/apple-iphone-se-mxvv2hn-a-original-imafrcqmfxhcrpsb.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Blue, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/s/n/i/iphone-13-mlpk3hn-a-apple-original-imag6vpyrhqjgqzw.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Starlight, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/h/w/1/iphone-13-mlpg3hn-a-apple-original-imag6vpy84hrnjyz.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 ((PRODUCT)RED, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/e/e/r/iphone-13-mlpj3hn-a-apple-original-imag6vpykhzqhmgh.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹74,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/l0igvww0/mobile/r/q/m/-original-imagca5ajerqpfjy.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Midnight, 512 GB)',
#   'Product_Description': '512 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹1,04,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/f/c/g/iphone-13-mlpf3hn-a-apple-original-imag6vzzzfa5ndzm.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Green, 512 GB)',
#   'Product_Description': '512 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹1,04,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/l0igvww0/mobile/r/q/m/-original-imagca5ajerqpfjy.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 13 (Green, 256 GB)',
#   'Product_Description': '256 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip ProcessorBrand Warranty for 1 Year',
#   'Product_price': '₹84,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/l0igvww0/mobile/r/q/m/-original-imagca5ajerqpfjy.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Red, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/c/u/7/apple-iphone-11-mhdd3hn-a-original-imafwqephghanvyr.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Black, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/5/x/8/apple-iphone-11-mhdh3hn-a-original-imafwqepcdfxrmhn.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Purple, 64 GB)',
#   'Product_Description': '64 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹46,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/g/k/e/apple-iphone-11-mhdf3hn-a-original-imafwqepygpnkgez.jpeg?q=70'},
#  {'Product_name': 'APPLE iPhone 11 (Green, 128 GB)',
#   'Product_Description': '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip ProcessorBrand Warranty of 1 Year',
#   'Product_price': '₹51,900',
#   'Product_ratings': '4.6',
#   'Image': 'https://rukminim2.flixcart.com/image/312/312/kgiaykw0/mobile/4/b/f/apple-iphone-11-mhdn3hn-a-original-imafwqeps9gkq9zd.jpeg?q=70'}]

# %%
len(reviews)
# Out:
# 69
